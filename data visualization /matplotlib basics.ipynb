# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(2, 20, 1000)

# %%
m,c = 3, 10

# %%
y = m * x + c

# %%
plt.scatter(x, y)

# %%
noise = np.random.randn(1000) *5

# %%
y_mod = y + noise

# %%
plt.scatter(x,y_mod)

# %%
x= np.random.randn(10000)

# %% [markdown]
#     randn --> whatever random integers we get,if we plot a graph, it will look like standard deviation
#     most numbers will be between 0-1

# %%
out = plt.hist(x, bins=120 )

# %%
out = plt.pie([10,20,30], explode=[0,.1,0], shadow=True, radius=1)

# %%
import seaborn as sns

# %%
x= np.random.randn(10000)

# %%
sns.displot(x, bins=30)

# %%
data = sns.load_dataset("tips")

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data["total_bill"], data["tip"], hue=data["smoker"])
# Out:
# /home/kph/.local/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.violinplot(y=data.total_bill)
# Out:
# <AxesSubplot:ylabel='total_bill'>

# %%
from sklearn.datasets import load_boston

# %%
x ,y = load_boston(return_X_y = True)

# %%
sns.violinplot(y=y)
# Out:
# <AxesSubplot:>
